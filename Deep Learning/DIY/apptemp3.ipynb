# %%
import pandas as pd
df = pd.read_csv("Salary_data.csv")
df.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
df.dropna(inplace=True)
df.isna().sum()
# Out:
# Age                    0
# Gender                 0
# Education Level        0
# Job Title              0
# Years of Experience    0
# Salary                 0
# dtype: int64

# %%
dummies = pd.get_dummies(df[['Gender', 'Education Level', 'Job Title']])
dummies.head()
# Out:
#    Gender_Female  Gender_Male  Gender_Other  Education Level_Bachelor's  \
# 0          False         True         False                        True
# 1           True        False         False                       False
# 2          False         True         False                       False
# 3           True        False         False                        True
# 4          False         True         False                       False
#
#    Education Level_Bachelor's Degree  Education Level_High School  \
# 0                              False                        False
# 1                              False                        False
# 2                              False                        False
# 3                              False                        False
# 4                              False                        False
#
#    Education Level_Master's  Education Level_Master's Degree  \
# 0                     False                            False
# ...

# %%
df = df.drop(['Gender', 'Education Level', 'Job Title'], axis='columns')
df = pd.concat([dummies, df], axis='columns')
df.head()
# Out:
#    Gender_Female  Gender_Male  Gender_Other  Education Level_Bachelor's  \
# 0          False         True         False                        True
# 1           True        False         False                       False
# 2          False         True         False                       False
# 3           True        False         False                        True
# 4          False         True         False                       False
#
#    Education Level_Bachelor's Degree  Education Level_High School  \
# 0                              False                        False
# 1                              False                        False
# 2                              False                        False
# 3                              False                        False
# 4                              False                        False
#
#    Education Level_Master's  Education Level_Master's Degree  \
# 0                     False                            False
# ...

# %%
X = df.drop(['Salary'], axis='columns')
y = df.Salary
y.head()
# Out:
# 0     90000.0
# 1     65000.0
# 2    150000.0
# 3     60000.0
# 4    200000.0
# Name: Salary, dtype: float64

# %%
def Standardize(df):
    for feature_name in df.columns: # The train data
        if df[feature_name].dtype in ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']:
            mean_value = df[feature_name].mean()
            std_value = df[feature_name].std()
            df[feature_name] = (df[feature_name] - mean_value) / std_value
        elif df[feature_name].dtype == 'bool':
            df[feature_name] = df[feature_name].astype(float)
    return df

# %%
X = Standardize(X)
y = Standardize(pd.DataFrame(y))
y = y.squeeze()
X.shape
# Out:
# (6698, 203)

# %%
# This is the point where the code can be more similar among all of the neural networks
# assign random weights to all of the inputs (203 inputs)
import numpy as np
weights = []
for weight in range(203):
    weights.append(np.random.random_sample())

# %%
# Main forward propogation
for x in range(1):
    output = np.dot(X, weights) # This is the sum for each row
# Out:
# (6698,)
