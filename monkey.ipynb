# %%
import pandas as pd
df = pd.read_csv("results.csv", sep='|')
df.head()
# Out:
#                         _id isPb    wpm    acc  rawWpm  consistency  \
# 0  64b2eeba73193c702ee6f7f2  NaN  46.90  93.33   46.90        50.88
# 1  64b2ee8373193c702ee6f6ad  NaN  55.46  95.95   55.46        63.65
# 2  64b2ee6273193c702ee6f5ee  NaN  54.25  94.55   54.25        62.40
# 3  64b2ee2173193c702ee6f484  NaN  54.11  89.77   54.11        53.81
# 4  64b2edf073193c702ee6f35a  NaN  50.26  91.28   51.75        51.89
#
#    charStats   mode mode2  quoteLength  ...  punctuation  numbers  language  \
# 0  180,0,0,0  quote  5000          1.0  ...        False    False   english
# 1  140,0,0,0  quote  2341          1.0  ...        False    False   english
# 2  256,0,0,0  quote   849          1.0  ...        False    False   english
# 3  190,0,0,0  quote   138          1.0  ...        False    False   english
# 4  135,1,1,0  quote  5425          1.0  ...        False    False   english
#
#    funbox  difficulty  lazyMode blindMode bailedOut tags      timestamp
# ...

# %%
keep = ['wpm', 'acc', 'rawWpm', 'consistency', 'mode', 'timestamp']
df = df[keep]
df.head()
# Out:
#      wpm    acc  rawWpm  consistency   mode      timestamp
# 0  46.90  93.33   46.90        50.88  quote  1689448088505
# 1  55.46  95.95   55.46        63.65  quote  1689448033833
# 2  54.25  94.55   54.25        62.40  quote  1689448000966
# 3  54.11  89.77   54.11        53.81  quote  1689447936349
# 4  50.26  91.28   51.75        51.89  quote  1689447887014

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
plt.xlabel('time')
plt.ylabel('wpm')
plt.scatter(df.index,df.wpm,color='red',marker='+')
